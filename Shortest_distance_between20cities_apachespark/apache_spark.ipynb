# %%
pip install pyspark
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyspark in /home/varun/.local/lib/python3.10/site-packages (3.5.5)
# Requirement already satisfied: py4j==0.10.9.7 in /home/varun/.local/lib/python3.10/site-packages (from pyspark) (0.10.9.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
# === Install Required Packages ===
# !pip install openrouteservice pandas requests

# === IMPORTS ===
import pandas as pd
import openrouteservice
import requests
import time

# === ORS API Key ===
ORS_API_KEY = '5b3ce3597851110001cf6248d3ad9e160c2243728d2f5ef309fdce20'
client = openrouteservice.Client(key=ORS_API_KEY)

# === WeatherAPI Key ===
WEATHER_API_KEY = 'aa46c37c5b04427fa3d201341251404'

# === City Coordinates ===
citiescordins = {
    "Nashville, TN": [-86.7816, 36.1627],
    "Salt Lake City, UT": [-111.8910, 40.7608],
    "Denver, CO": [-104.9903, 39.7392],
    "New York City, NY": [-74.0060, 40.7128],
    "Cincinnati, OH": [-84.5120, 39.1031],
    "Seattle, WA": [-122.3321, 47.6062],
    "Orlando, FL": [-81.3792, 28.5383],
    "Washington, DC": [-77.0369, 38.9072],
    "Detroit, MI": [-83.0458, 42.3314],
    "Houston, TX": [-95.3698, 29.7604],
    "Miami, FL": [-80.1918, 25.7617],
    "Baltimore, MD": [-76.6122, 39.2904],
    "Pittsburgh, PA": [-79.9959, 40.4406],
    "Las Vegas, NV": [-115.1398, 36.1699],
    "Chicago, IL": [-87.6298, 41.8781],
    "Boston, MA": [-71.0589, 42.3601],
    "Boise, ID": [-116.2023, 43.6150],
    "Portland, ME": [-70.2553, 43.6591],
    "Portland, OR": [-122.6765, 45.5051],
    "Harrisburg, PA": [-76.8844, 40.2732]
}

# === Create City Pair Routes ===
routes = []
for source in citiescordins:
    for destination in citiescordins:
        if source != destination:
            routes.append({
                "sourcecity": source,
                "destinationcity": destination,
                "sourcelon": citiescordins[source][0],
                "sourcelat": citiescordins[source][1],
                "destlon": citiescordins[destination][0],
                "destlat": citiescordins[destination][1]
            })

df_routes = pd.DataFrame(routes)
df_routes.to_csv("city_pairs.csv", index=False)
print("city_pairs.csv created successfully.")

# === Load city pairs for routing ===
df = pd.read_csv("city_pairs.csv")

# === ORS: Get Distance + Duration ===
routes_data = []

for idx, row in df.iterrows():
    source_coords = (row['sourcelon'], row['sourcelat'])
    dest_coords = (row['destlon'], row['destlat'])
    
    try:
        route = client.directions((source_coords, dest_coords), profile='driving-hgv', format='geojson')
        segment = route['features'][0]['properties']['segments'][0]

        routes_data.append({
            "sourcecity": row['sourcecity'],
            "destinationcity": row['destinationcity'],
            "distance_km": round(segment['distance'] / 1000, 2),
            "duration_hr": round(segment['duration'] / 3600, 2)
        })

        print(f"{row['sourcecity']} → {row['destinationcity']}: {segment['distance']/1000:.2f} km, {segment['duration']/3600:.2f} hrs")
        time.sleep(1)

    except Exception as e:
        print(f" Error fetching route: {row['sourcecity']} → {row['destinationcity']}: {e}")
        routes_data.append({
            "sourcecity": row['sourcecity'],
            "destinationcity": row['destinationcity'],
            "distance_km": None,
            "duration_hr": None
        })
        time.sleep(2)

df_routes_final = pd.DataFrame(routes_data)

# === WEATHER API: Enrich with Destination Weather ===
df_routes_final['city_for_weather'] = df_routes_final['destinationcity'].apply(lambda x: x.split(',')[0].strip())
unique_cities = df_routes_final['city_for_weather'].unique()

weather_data = {}

for city in unique_cities:
    try:
        url = f"http://api.weatherapi.com/v1/current.json?key={WEATHER_API_KEY}&q={city}"
        response = requests.get(url, timeout=5)
        data = response.json()

        if response.status_code == 200 and "current" in data:
            description = data['current']['condition']['text']
            temp_c = round(data['current']['temp_c'], 2)
        else:
            description = "unknown"
            temp_c = None

        weather_data[city] = {
            'weather_description': description,
            'temperature_c': temp_c
        }

        print(f" {city}: {description}, {temp_c}°C")
        time.sleep(1)

    except Exception as e:
        print(f" Error fetching weather for {city}: {e}")
        weather_data[city] = {
            'weather_description': 'unknown',
            'temperature_c': None
        }

df_routes_final['weather_description'] = df_routes_final['city_for_weather'].map(lambda x: weather_data[x]['weather_description'])
df_routes_final['temperature_c'] = df_routes_final['city_for_weather'].map(lambda x: weather_data[x]['temperature_c'])

df_routes_final.drop(columns=['city_for_weather'], inplace=True)

# === Save Final Output ===
df_routes_final.to_csv("final_route_data.csv", index=False)
print("\n final_route_data.csv saved with distance, duration, and weather.")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openrouteservice in /home/varun/.local/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: pandas in /home/varun/.local/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: requests in /home/varun/.local/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: numpy>=1.22.4 in /home/varun/.local/lib/python3.10/site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/varun/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/varun/.local/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/varun/.local/lib/python3.10/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests) (2020.6.20)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# city_pairs.csv created successfully.
# Nashville, TN → Salt Lake City, UT: 2633.14 km, 37.36 hrs
# Nashville, TN → Denver, CO: 1869.60 km, 27.05 hrs
# Nashville, TN → New York City, NY: 1429.29 km, 20.94 hrs
# Nashville, TN → Cincinnati, OH: 462.86 km, 6.49 hrs
# Nashville, TN → Seattle, WA: 3865.20 km, 51.90 hrs
# Nashville, TN → Orlando, FL: 1105.63 km, 16.59 hrs
# Nashville, TN → Washington, DC: 1065.64 km, 15.62 hrs
# Nashville, TN → Detroit, MI: 910.24 km, 12.44 hrs
# Nashville, TN → Houston, TX: 1263.15 km, 17.14 hrs
# Nashville, TN → Miami, FL: 1466.96 km, 21.99 hrs
# Nashville, TN → Baltimore, MD: 1131.37 km, 16.42 hrs
# Nashville, TN → Pittsburgh, PA: 940.24 km, 12.98 hrs
# Nashville, TN → Las Vegas, NV: 2888.57 km, 40.78 hrs
# Nashville, TN → Chicago, IL: 745.89 km, 10.65 hrs
# Nashville, TN → Boston, MA: 1814.89 km, 26.59 hrs
# Nashville, TN → Boise, ID: 3109.27 km, 43.00 hrs
# Nashville, TN → Portland, ME: 1974.48 km, 29.14 hrs
# Nashville, TN → Portland, OR: 3797.20 km, 51.91 hrs
# Nashville, TN → Harrisburg, PA: 1162.69 km, 16.65 hrs
# Salt Lake City, UT → Nashville, TN: 2627.31 km, 37.44 hrs
# Salt Lake City, UT → Denver, CO: 789.59 km, 11.22 hrs
# Salt Lake City, UT → New York City, NY: 3506.38 km, 49.98 hrs
# Salt Lake City, UT → Cincinnati, OH: 2629.15 km, 36.86 hrs
# Salt Lake City, UT → Seattle, WA: 1342.78 km, 16.89 hrs
# Salt Lake City, UT → Orlando, FL: 3757.79 km, 53.77 hrs
# Salt Lake City, UT → Washington, DC: 3350.96 km, 47.98 hrs
# Salt Lake City, UT → Detroit, MI: 2678.68 km, 37.13 hrs
# Salt Lake City, UT → Houston, TX: 2428.55 km, 35.09 hrs
# Salt Lake City, UT → Miami, FL: 4119.12 km, 59.18 hrs
# Salt Lake City, UT → Baltimore, MD: 3357.87 km, 47.98 hrs
# Salt Lake City, UT → Pittsburgh, PA: 2968.32 km, 42.22 hrs
# Salt Lake City, UT → Las Vegas, NV: 676.66 km, 9.89 hrs
# Salt Lake City, UT → Chicago, IL: 2251.87 km, 31.83 hrs
# Salt Lake City, UT → Boston, MA: 3828.77 km, 54.02 hrs
# Salt Lake City, UT → Boise, ID: 547.15 km, 6.92 hrs
# Salt Lake City, UT → Portland, ME: 3988.36 km, 56.57 hrs
# Salt Lake City, UT → Portland, OR: 1235.08 km, 15.83 hrs
# Salt Lake City, UT → Harrisburg, PA: 3287.83 km, 46.81 hrs
# Denver, CO → Nashville, TN: 1865.39 km, 27.00 hrs
# Denver, CO → Salt Lake City, UT: 788.84 km, 11.19 hrs
# Denver, CO → New York City, NY: 2872.11 km, 41.16 hrs
# Denver, CO → Cincinnati, OH: 1974.29 km, 27.93 hrs
# Denver, CO → Seattle, WA: 2126.63 km, 27.74 hrs
# Denver, CO → Orlando, FL: 2975.05 km, 42.76 hrs
# Denver, CO → Washington, DC: 2716.69 km, 39.16 hrs
# Denver, CO → Detroit, MI: 2044.41 km, 28.31 hrs
# Denver, CO → Houston, TX: 1645.82 km, 24.07 hrs
# Denver, CO → Miami, FL: 3336.39 km, 48.17 hrs
# Denver, CO → Baltimore, MD: 2723.60 km, 39.16 hrs
# Denver, CO → Pittsburgh, PA: 2334.05 km, 33.40 hrs
# Denver, CO → Las Vegas, NV: 1203.72 km, 16.94 hrs
# Denver, CO → Chicago, IL: 1617.60 km, 23.01 hrs
# Denver, CO → Boston, MA: 3194.50 km, 45.20 hrs
# Denver, CO → Boise, ID: 1331.01 km, 17.76 hrs
# Denver, CO → Portland, ME: 3354.10 km, 47.74 hrs
# Denver, CO → Portland, OR: 2018.93 km, 26.68 hrs
# Denver, CO → Harrisburg, PA: 2653.56 km, 37.99 hrs
# New York City, NY → Nashville, TN: 1430.06 km, 20.99 hrs
# New York City, NY → Salt Lake City, UT: 3503.53 km, 49.93 hrs
# New York City, NY → Denver, CO: 2870.12 km, 41.16 hrs
# New York City, NY → Cincinnati, OH: 1027.69 km, 15.84 hrs
# New York City, NY → Seattle, WA: 4588.10 km, 62.10 hrs
# New York City, NY → Orlando, FL: 1738.04 km, 25.91 hrs
# New York City, NY → Washington, DC: 378.83 km, 6.12 hrs
# New York City, NY → Detroit, MI: 997.29 km, 14.67 hrs
# New York City, NY → Houston, TX: 2618.35 km, 37.23 hrs
# New York City, NY → Miami, FL: 2068.11 km, 30.95 hrs
# New York City, NY → Baltimore, MD: 310.45 km, 4.97 hrs
# New York City, NY → Pittsburgh, PA: 597.25 km, 9.34 hrs
# New York City, NY → Las Vegas, NV: 4065.65 km, 57.88 hrs
# New York City, NY → Chicago, IL: 1279.97 km, 18.72 hrs
# New York City, NY → Boston, MA: 351.98 km, 6.22 hrs
# New York City, NY → Boise, ID: 3979.65 km, 55.56 hrs
# New York City, NY → Portland, ME: 511.57 km, 8.77 hrs
# New York City, NY → Portland, OR: 4700.03 km, 64.15 hrs
# New York City, NY → Harrisburg, PA: 275.92 km, 4.57 hrs
# Cincinnati, OH → Nashville, TN: 462.34 km, 6.45 hrs
# Cincinnati, OH → Salt Lake City, UT: 2633.27 km, 36.97 hrs
# Cincinnati, OH → Denver, CO: 1919.82 km, 28.06 hrs
# Cincinnati, OH → New York City, NY: 1028.46 km, 15.80 hrs
# Cincinnati, OH → Seattle, WA: 3756.05 km, 50.34 hrs
# Cincinnati, OH → Orlando, FL: 1428.48 km, 20.75 hrs
# Cincinnati, OH → Washington, DC: 820.95 km, 12.33 hrs
# Cincinnati, OH → Detroit, MI: 422.87 km, 6.39 hrs
# Cincinnati, OH → Houston, TX: 1731.31 km, 23.00 hrs
# Cincinnati, OH → Miami, FL: 1789.81 km, 26.16 hrs
# Cincinnati, OH → Baltimore, MD: 824.74 km, 12.34 hrs
# Cincinnati, OH → Pittsburgh, PA: 477.44 km, 7.15 hrs
# Cincinnati, OH → Las Vegas, NV: 3118.50 km, 44.78 hrs
# Cincinnati, OH → Chicago, IL: 474.97 km, 7.34 hrs
# Cincinnati, OH → Boston, MA: 1394.87 km, 21.23 hrs
# Cincinnati, OH → Boise, ID: 3109.40 km, 42.60 hrs
# Cincinnati, OH → Portland, ME: 1554.47 km, 23.78 hrs
# Cincinnati, OH → Portland, OR: 3797.32 km, 51.52 hrs
# Cincinnati, OH → Harrisburg, PA: 760.76 km, 11.48 hrs
# Seattle, WA → Nashville, TN: 3859.65 km, 52.09 hrs
# Seattle, WA → Salt Lake City, UT: 1346.24 km, 16.94 hrs
# Seattle, WA → Denver, CO: 2128.41 km, 27.83 hrs
# Seattle, WA → New York City, NY: 4602.82 km, 62.20 hrs
# Seattle, WA → Cincinnati, OH: 3750.57 km, 50.44 hrs
# Seattle, WA → Orlando, FL: 4960.06 km, 68.55 hrs
# Seattle, WA → Washington, DC: 4447.40 km, 60.20 hrs
# Seattle, WA → Detroit, MI: 3778.96 km, 49.38 hrs
# Seattle, WA → Houston, TX: 3731.19 km, 51.59 hrs
# Seattle, WA → Miami, FL: 5321.39 km, 73.96 hrs
# Seattle, WA → Baltimore, MD: 4454.31 km, 60.20 hrs
# Seattle, WA → Pittsburgh, PA: 4064.76 km, 54.44 hrs
# Seattle, WA → Las Vegas, NV: 1800.86 km, 23.76 hrs
# Seattle, WA → Chicago, IL: 3325.93 km, 43.68 hrs
# Seattle, WA → Boston, MA: 4879.91 km, 65.81 hrs
# Seattle, WA → Boise, ID: 804.09 km, 10.27 hrs
# Seattle, WA → Portland, ME: 4795.46 km, 67.22 hrs
# Seattle, WA → Portland, OR: 293.53 km, 4.36 hrs
# Seattle, WA → Harrisburg, PA: 4384.26 km, 59.02 hrs
# Orlando, FL → Nashville, TN: 1106.44 km, 16.67 hrs
# Orlando, FL → Salt Lake City, UT: 3730.49 km, 53.86 hrs
# Orlando, FL → Denver, CO: 2984.87 km, 42.82 hrs
# Orlando, FL → New York City, NY: 1737.24 km, 25.79 hrs
# Orlando, FL → Cincinnati, OH: 1427.05 km, 20.78 hrs
# Orlando, FL → Seattle, WA: 4962.55 km, 68.40 hrs
# Orlando, FL → Washington, DC: 1361.51 km, 19.90 hrs
# Orlando, FL → Detroit, MI: 1848.01 km, 27.08 hrs
# Orlando, FL → Houston, TX: 1549.73 km, 22.27 hrs
# Orlando, FL → Miami, FL: 378.22 km, 5.81 hrs
# Orlando, FL → Baltimore, MD: 1435.94 km, 21.19 hrs
# Orlando, FL → Pittsburgh, PA: 1553.91 km, 22.96 hrs
# Orlando, FL → Las Vegas, NV: 3767.91 km, 52.98 hrs
# Orlando, FL → Chicago, IL: 1813.00 km, 26.71 hrs
# Orlando, FL → Boston, MA: 2082.93 km, 31.62 hrs
# Orlando, FL → Boise, ID: 4206.62 km, 59.49 hrs
# Orlando, FL → Portland, ME: 2242.52 km, 34.17 hrs
# Orlando, FL → Portland, OR: 4894.54 km, 68.41 hrs
# Orlando, FL → Harrisburg, PA: 1582.93 km, 22.80 hrs
# Washington, DC → Nashville, TN: 1065.56 km, 15.65 hrs
# Washington, DC → Salt Lake City, UT: 3349.38 km, 47.90 hrs
# Washington, DC → Denver, CO: 2715.97 km, 39.13 hrs
# Washington, DC → New York City, NY: 377.36 km, 5.95 hrs
# Washington, DC → Cincinnati, OH: 823.20 km, 12.36 hrs
# Washington, DC → Seattle, WA: 4433.95 km, 60.08 hrs
# Washington, DC → Orlando, FL: 1361.53 km, 19.89 hrs
# Washington, DC → Detroit, MI: 843.15 km, 12.65 hrs
# Washington, DC → Houston, TX: 2253.85 km, 31.88 hrs
# Washington, DC → Miami, FL: 1691.59 km, 24.93 hrs
# Washington, DC → Baltimore, MD: 76.06 km, 1.35 hrs
# Washington, DC → Pittsburgh, PA: 393.97 km, 6.22 hrs
# Washington, DC → Las Vegas, NV: 3911.50 km, 55.85 hrs
# Washington, DC → Chicago, IL: 1125.83 km, 16.69 hrs
# Washington, DC → Boston, MA: 723.06 km, 11.78 hrs
# Washington, DC → Boise, ID: 3825.51 km, 53.53 hrs
# Washington, DC → Portland, ME: 882.65 km, 14.33 hrs
# Washington, DC → Portland, OR: 4545.89 km, 62.13 hrs
# Washington, DC → Harrisburg, PA: 204.08 km, 3.34 hrs
# Detroit, MI → Nashville, TN: 907.88 km, 12.54 hrs
# Detroit, MI → Salt Lake City, UT: 2676.99 km, 37.02 hrs
# Detroit, MI → Denver, CO: 2043.58 km, 28.26 hrs
# Detroit, MI → New York City, NY: 997.70 km, 14.53 hrs
# Detroit, MI → Cincinnati, OH: 423.39 km, 6.27 hrs
# Detroit, MI → Seattle, WA: 3766.08 km, 49.21 hrs
# Detroit, MI → Orlando, FL: 1849.70 km, 26.95 hrs
# Detroit, MI → Washington, DC: 842.28 km, 12.54 hrs
# Detroit, MI → Houston, TX: 2101.89 km, 28.57 hrs
# Detroit, MI → Miami, FL: 2186.39 km, 32.17 hrs
# Detroit, MI → Baltimore, MD: 849.20 km, 12.54 hrs
# Detroit, MI → Pittsburgh, PA: 459.64 km, 6.78 hrs
# Detroit, MI → Las Vegas, NV: 3239.11 km, 44.97 hrs
# Detroit, MI → Chicago, IL: 458.96 km, 5.87 hrs
# Detroit, MI → Boston, MA: 1158.90 km, 17.25 hrs
# Detroit, MI → Boise, ID: 3153.11 km, 42.66 hrs
# Detroit, MI → Portland, ME: 1318.50 km, 19.80 hrs
# Detroit, MI → Portland, OR: 3878.02 km, 51.26 hrs
# Detroit, MI → Harrisburg, PA: 779.15 km, 11.36 hrs
# Houston, TX → Nashville, TN: 1263.18 km, 17.15 hrs
# Houston, TX → Salt Lake City, UT: 2388.16 km, 34.90 hrs
# Houston, TX → Denver, CO: 1644.19 km, 24.16 hrs
# Houston, TX → New York City, NY: 2617.26 km, 37.22 hrs
# Houston, TX → Cincinnati, OH: 1734.87 km, 23.11 hrs
# Houston, TX → Seattle, WA: 3830.75 km, 51.53 hrs
# Houston, TX → Orlando, FL: 1549.56 km, 22.34 hrs
# Houston, TX → Washington, DC: 2253.61 km, 31.90 hrs
# Houston, TX → Detroit, MI: 2104.73 km, 28.46 hrs
# Houston, TX → Miami, FL: 1910.89 km, 27.74 hrs
# Houston, TX → Baltimore, MD: 2319.35 km, 32.71 hrs
# Houston, TX → Pittsburgh, PA: 2212.25 km, 29.61 hrs
# Houston, TX → Las Vegas, NV: 2317.20 km, 33.26 hrs
# Houston, TX → Chicago, IL: 1752.13 km, 23.96 hrs
# Houston, TX → Boston, MA: 3002.86 km, 42.87 hrs
# Houston, TX → Boise, ID: 2934.91 km, 41.61 hrs
# Houston, TX → Portland, ME: 3162.45 km, 45.42 hrs
# Houston, TX → Portland, OR: 3622.83 km, 50.52 hrs
# Houston, TX → Harrisburg, PA: 2350.66 km, 32.93 hrs
# Miami, FL → Nashville, TN: 1468.10 km, 22.08 hrs
# Miami, FL → Salt Lake City, UT: 4092.15 km, 59.28 hrs
# Miami, FL → Denver, CO: 3346.54 km, 48.24 hrs
# Miami, FL → New York City, NY: 2067.21 km, 30.86 hrs
# Miami, FL → Cincinnati, OH: 1788.71 km, 26.20 hrs
# Miami, FL → Seattle, WA: 5324.21 km, 73.81 hrs
# Miami, FL → Orlando, FL: 377.89 km, 5.82 hrs
# Miami, FL → Washington, DC: 1691.48 km, 24.97 hrs
# Miami, FL → Detroit, MI: 2193.53 km, 32.34 hrs
# Miami, FL → Houston, TX: 1911.39 km, 27.69 hrs
# Miami, FL → Baltimore, MD: 1765.91 km, 26.26 hrs
# Miami, FL → Pittsburgh, PA: 1883.88 km, 28.03 hrs
# Miami, FL → Las Vegas, NV: 4129.57 km, 58.40 hrs
# Miami, FL → Chicago, IL: 2174.67 km, 32.12 hrs
# Miami, FL → Boston, MA: 2412.90 km, 36.69 hrs
# Miami, FL → Boise, ID: 4568.28 km, 64.91 hrs
# Miami, FL → Portland, ME: 2572.49 km, 39.24 hrs
# Miami, FL → Portland, OR: 5256.21 km, 73.83 hrs
# Miami, FL → Harrisburg, PA: 1912.90 km, 27.87 hrs
# Baltimore, MD → Nashville, TN: 1131.62 km, 16.46 hrs
# Baltimore, MD → Salt Lake City, UT: 3352.85 km, 47.82 hrs
# Baltimore, MD → Denver, CO: 2719.44 km, 39.06 hrs
# Baltimore, MD → New York City, NY: 308.34 km, 4.84 hrs
# Baltimore, MD → Cincinnati, OH: 826.21 km, 12.38 hrs
# Baltimore, MD → Seattle, WA: 4437.42 km, 60.00 hrs
# Baltimore, MD → Orlando, FL: 1433.88 km, 21.18 hrs
# Baltimore, MD → Washington, DC: 74.67 km, 1.39 hrs
# Baltimore, MD → Detroit, MI: 846.62 km, 12.57 hrs
# Baltimore, MD → Houston, TX: 2319.91 km, 32.70 hrs
# Baltimore, MD → Miami, FL: 1763.95 km, 26.22 hrs
# Baltimore, MD → Pittsburgh, PA: 397.44 km, 6.15 hrs
# Baltimore, MD → Las Vegas, NV: 3914.97 km, 55.77 hrs
# Baltimore, MD → Chicago, IL: 1129.30 km, 16.61 hrs
# Baltimore, MD → Boston, MA: 654.03 km, 10.68 hrs
# Baltimore, MD → Boise, ID: 3828.98 km, 53.46 hrs
# Baltimore, MD → Portland, ME: 813.63 km, 13.22 hrs
# Baltimore, MD → Portland, OR: 4549.36 km, 62.05 hrs
# Baltimore, MD → Harrisburg, PA: 128.00 km, 2.13 hrs
# Pittsburgh, PA → Nashville, TN: 940.89 km, 12.97 hrs
# Pittsburgh, PA → Salt Lake City, UT: 2965.82 km, 42.09 hrs
# Pittsburgh, PA → Denver, CO: 2332.41 km, 33.33 hrs
# Pittsburgh, PA → New York City, NY: 592.17 km, 9.30 hrs
# Pittsburgh, PA → Cincinnati, OH: 461.20 km, 7.21 hrs
# Pittsburgh, PA → Seattle, WA: 4050.39 km, 54.27 hrs
# Pittsburgh, PA → Orlando, FL: 1555.49 km, 22.94 hrs
# Pittsburgh, PA → Washington, DC: 387.59 km, 6.16 hrs
# Pittsburgh, PA → Detroit, MI: 459.59 km, 6.84 hrs
# Pittsburgh, PA → Houston, TX: 2209.85 km, 29.52 hrs
# Pittsburgh, PA → Miami, FL: 1885.56 km, 27.98 hrs
# Pittsburgh, PA → Baltimore, MD: 394.50 km, 6.16 hrs
# Pittsburgh, PA → Las Vegas, NV: 3527.94 km, 50.04 hrs
# Pittsburgh, PA → Chicago, IL: 742.27 km, 10.88 hrs
# Pittsburgh, PA → Boston, MA: 937.39 km, 14.38 hrs
# Pittsburgh, PA → Boise, ID: 3441.94 km, 47.73 hrs
# Pittsburgh, PA → Portland, ME: 1096.98 km, 16.92 hrs
# Pittsburgh, PA → Portland, OR: 4162.33 km, 56.32 hrs
# Pittsburgh, PA → Harrisburg, PA: 324.46 km, 4.99 hrs
# Las Vegas, NV → Nashville, TN: 2888.23 km, 40.73 hrs
# Las Vegas, NV → Salt Lake City, UT: 676.18 km, 9.90 hrs
# Las Vegas, NV → Denver, CO: 1202.88 km, 17.30 hrs
# Las Vegas, NV → New York City, NY: 4066.36 km, 58.23 hrs
# Las Vegas, NV → Cincinnati, OH: 3170.31 km, 45.02 hrs
# Las Vegas, NV → Seattle, WA: 1799.87 km, 23.66 hrs
# Las Vegas, NV → Orlando, FL: 3768.77 km, 52.95 hrs
# Las Vegas, NV → Washington, DC: 3953.09 km, 56.28 hrs
# Las Vegas, NV → Detroit, MI: 3238.66 km, 45.37 hrs
# Las Vegas, NV → Houston, TX: 2298.61 km, 33.25 hrs
# Las Vegas, NV → Miami, FL: 4130.10 km, 58.35 hrs
# Las Vegas, NV → Baltimore, MD: 3917.85 km, 56.23 hrs
# Las Vegas, NV → Pittsburgh, PA: 3528.30 km, 50.47 hrs
# Las Vegas, NV → Chicago, IL: 2811.85 km, 40.08 hrs
# Las Vegas, NV → Boston, MA: 4388.75 km, 62.26 hrs
# Las Vegas, NV → Boise, ID: 1004.25 km, 13.69 hrs
# Las Vegas, NV → Portland, ME: 4548.35 km, 64.81 hrs
# Las Vegas, NV → Portland, OR: 1692.18 km, 22.61 hrs
# Las Vegas, NV → Harrisburg, PA: 3847.81 km, 55.05 hrs
# Chicago, IL → Nashville, TN: 726.61 km, 10.51 hrs
# Chicago, IL → Salt Lake City, UT: 2248.71 km, 31.71 hrs
# Chicago, IL → Denver, CO: 1615.30 km, 22.95 hrs
# Chicago, IL → New York City, NY: 1280.49 km, 18.61 hrs
# Chicago, IL → Cincinnati, OH: 479.21 km, 7.31 hrs
# Chicago, IL → Seattle, WA: 3311.15 km, 43.46 hrs
# Chicago, IL → Orlando, FL: 1817.75 km, 26.69 hrs
# Chicago, IL → Washington, DC: 1125.07 km, 16.61 hrs
# Chicago, IL → Detroit, MI: 454.77 km, 5.82 hrs
# Chicago, IL → Houston, TX: 1753.03 km, 23.90 hrs
# Chicago, IL → Miami, FL: 2179.08 km, 32.09 hrs
# Chicago, IL → Baltimore, MD: 1131.99 km, 16.61 hrs
# Chicago, IL → Pittsburgh, PA: 742.44 km, 10.85 hrs
# Chicago, IL → Las Vegas, NV: 2810.83 km, 39.66 hrs
# Chicago, IL → Boston, MA: 1604.86 km, 22.72 hrs
# Chicago, IL → Boise, ID: 2724.83 km, 37.34 hrs
# Chicago, IL → Portland, ME: 1764.46 km, 25.26 hrs
# Chicago, IL → Portland, OR: 3423.08 km, 45.51 hrs
# Chicago, IL → Harrisburg, PA: 1061.94 km, 15.43 hrs
# Boston, MA → Nashville, TN: 1814.72 km, 26.59 hrs
# Boston, MA → Salt Lake City, UT: 3825.76 km, 53.90 hrs
# Boston, MA → Denver, CO: 3192.35 km, 45.13 hrs
# Boston, MA → New York City, NY: 359.58 km, 6.10 hrs
# Boston, MA → Cincinnati, OH: 1409.22 km, 21.19 hrs
# Boston, MA → Seattle, WA: 4877.61 km, 65.77 hrs
# Boston, MA → Orlando, FL: 2090.43 km, 31.54 hrs
# Boston, MA → Washington, DC: 731.22 km, 11.75 hrs
# Boston, MA → Detroit, MI: 1159.50 km, 17.26 hrs
# Boston, MA → Houston, TX: 3003.02 km, 42.83 hrs
# Boston, MA → Miami, FL: 2420.50 km, 36.58 hrs
# Boston, MA → Baltimore, MD: 662.84 km, 10.60 hrs
# Boston, MA → Pittsburgh, PA: 930.68 km, 14.30 hrs
# Boston, MA → Las Vegas, NV: 4387.88 km, 61.85 hrs
# Boston, MA → Chicago, IL: 1607.72 km, 22.75 hrs
# Boston, MA → Boise, ID: 4301.88 km, 59.53 hrs
# Boston, MA → Portland, ME: 173.87 km, 2.69 hrs
# Boston, MA → Portland, OR: 4989.54 km, 67.82 hrs
# Boston, MA → Harrisburg, PA: 660.59 km, 10.17 hrs
# Boise, ID → Nashville, TN: 3102.78 km, 43.04 hrs
# Boise, ID → Salt Lake City, UT: 548.92 km, 6.88 hrs
# Boise, ID → Denver, CO: 1331.10 km, 17.76 hrs
# Boise, ID → New York City, NY: 3981.85 km, 55.58 hrs
# Boise, ID → Cincinnati, OH: 3104.62 km, 42.46 hrs
# Boise, ID → Seattle, WA: 802.32 km, 10.17 hrs
# Boise, ID → Orlando, FL: 4203.19 km, 59.51 hrs
# Boise, ID → Washington, DC: 3826.43 km, 53.58 hrs
# Boise, ID → Detroit, MI: 3154.15 km, 42.73 hrs
# Boise, ID → Houston, TX: 2933.87 km, 41.53 hrs
# Boise, ID → Miami, FL: 4564.52 km, 64.92 hrs
# Boise, ID → Baltimore, MD: 3833.34 km, 53.58 hrs
# Boise, ID → Pittsburgh, PA: 3443.79 km, 47.82 hrs
# Boise, ID → Las Vegas, NV: 1003.54 km, 13.69 hrs
# Boise, ID → Chicago, IL: 2727.34 km, 37.44 hrs
# Boise, ID → Boston, MA: 4304.24 km, 59.62 hrs
# Boise, ID → Portland, ME: 4463.84 km, 62.17 hrs
# Boise, ID → Portland, OR: 694.62 km, 9.11 hrs
# Boise, ID → Harrisburg, PA: 3763.30 km, 52.41 hrs
# Portland, ME → Nashville, TN: 1983.75 km, 29.20 hrs
# Portland, ME → Salt Lake City, UT: 3994.79 km, 56.50 hrs
# Portland, ME → Denver, CO: 3361.38 km, 47.74 hrs
# Portland, ME → New York City, NY: 528.61 km, 8.71 hrs
# Portland, ME → Cincinnati, OH: 1578.25 km, 23.80 hrs
# Portland, ME → Seattle, WA: 4834.16 km, 67.29 hrs
# Portland, ME → Orlando, FL: 2259.46 km, 34.15 hrs
# Portland, ME → Washington, DC: 900.25 km, 14.36 hrs
# Portland, ME → Detroit, MI: 1328.53 km, 19.87 hrs
# Portland, ME → Houston, TX: 3172.05 km, 45.43 hrs
# Portland, ME → Miami, FL: 2589.53 km, 39.19 hrs
# Portland, ME → Baltimore, MD: 831.87 km, 13.21 hrs
# Portland, ME → Pittsburgh, PA: 1099.71 km, 16.90 hrs
# Portland, ME → Las Vegas, NV: 4556.91 km, 64.45 hrs
# Portland, ME → Chicago, IL: 1776.75 km, 25.35 hrs
# Portland, ME → Boston, MA: 172.33 km, 2.69 hrs
# Portland, ME → Boise, ID: 4470.91 km, 62.14 hrs
# Portland, ME → Portland, OR: 4946.09 km, 69.34 hrs
# Portland, ME → Harrisburg, PA: 829.62 km, 12.78 hrs
# Portland, OR → Nashville, TN: 3789.27 km, 52.00 hrs
# Portland, OR → Salt Lake City, UT: 1235.41 km, 15.83 hrs
# Portland, OR → Denver, CO: 2017.59 km, 26.72 hrs
# Portland, OR → New York City, NY: 4711.74 km, 64.21 hrs
# Portland, OR → Cincinnati, OH: 3791.11 km, 51.42 hrs
# Portland, OR → Seattle, WA: 291.17 km, 4.27 hrs
# Portland, OR → Orlando, FL: 4889.68 km, 68.47 hrs
# Portland, OR → Washington, DC: 4556.32 km, 62.21 hrs
# Portland, OR → Detroit, MI: 3887.88 km, 51.39 hrs
# Portland, OR → Houston, TX: 3620.36 km, 50.48 hrs
# Portland, OR → Miami, FL: 5251.01 km, 73.87 hrs
# Portland, OR → Baltimore, MD: 4563.23 km, 62.21 hrs
# Portland, OR → Pittsburgh, PA: 4173.68 km, 56.45 hrs
# Portland, OR → Las Vegas, NV: 1690.03 km, 22.65 hrs
# Portland, OR → Chicago, IL: 3434.85 km, 45.70 hrs
# Portland, OR → Boston, MA: 4988.83 km, 67.82 hrs
# Portland, OR → Boise, ID: 693.26 km, 9.16 hrs
# Portland, OR → Portland, ME: 4904.38 km, 69.24 hrs
# Portland, OR → Harrisburg, PA: 4493.19 km, 61.04 hrs
# Harrisburg, PA → Nashville, TN: 1162.99 km, 16.69 hrs
# Harrisburg, PA → Salt Lake City, UT: 3285.36 km, 46.70 hrs
# Harrisburg, PA → Denver, CO: 2651.95 km, 37.94 hrs
# Harrisburg, PA → New York City, NY: 274.85 km, 4.54 hrs
# Harrisburg, PA → Cincinnati, OH: 760.39 km, 11.52 hrs
# Harrisburg, PA → Seattle, WA: 4369.94 km, 58.88 hrs
# Harrisburg, PA → Orlando, FL: 1583.85 km, 22.81 hrs
# Harrisburg, PA → Washington, DC: 203.13 km, 3.40 hrs
# Harrisburg, PA → Detroit, MI: 779.13 km, 11.45 hrs
# Harrisburg, PA → Houston, TX: 2351.29 km, 32.93 hrs
# Harrisburg, PA → Miami, FL: 1913.92 km, 27.86 hrs
# Harrisburg, PA → Baltimore, MD: 128.12 km, 2.12 hrs
# Harrisburg, PA → Pittsburgh, PA: 329.95 km, 5.02 hrs
# Harrisburg, PA → Las Vegas, NV: 3847.49 km, 54.65 hrs
# Harrisburg, PA → Chicago, IL: 1061.81 km, 15.49 hrs
# Harrisburg, PA → Boston, MA: 660.44 km, 10.19 hrs
# Harrisburg, PA → Boise, ID: 3761.49 km, 52.33 hrs
# Harrisburg, PA → Portland, ME: 820.04 km, 12.74 hrs
# Harrisburg, PA → Portland, OR: 4481.87 km, 60.93 hrs
#  Salt Lake City: Partly cloudy, 21.1°C
#  Denver: Sunny, 13.9°C
#  New York City: Partly Cloudy, 17.2°C
#  Cincinnati: Overcast, 19.4°C
#  Seattle: Overcast, 9.4°C
#  Orlando: Light rain, 22.8°C
#  Washington: Partly cloudy, 18.9°C
#  Detroit: Sunny, 15.3°C
#  Houston: Sunny, 19.3°C
#  Miami: Light rain, 24.4°C
#  Baltimore: Partly Cloudy, 21.7°C
#  Pittsburgh: Sunny, 17.8°C
#  Las Vegas: Sunny, 23.9°C
#  Chicago: Partly cloudy, 15.6°C
#  Boston: Sunny, 14.4°C
#  Boise: Partly Cloudy, 12.2°C
#  Portland: Overcast, 10.6°C
#  Harrisburg: Sunny, 17.2°C
#  Nashville: Partly cloudy, 19.4°C
#
#  final_route_data.csv saved with distance, duration, and weather.

# %%
df = pd.read_csv("final_route_data.csv")
df.head()
# Out:
#       sourcecity     destinationcity  distance_km  duration_hr  \
# 0  Nashville, TN  Salt Lake City, UT      2633.14        37.36
# 1  Nashville, TN          Denver, CO      1869.60        27.05
# 2  Nashville, TN   New York City, NY      1429.29        20.94
# 3  Nashville, TN      Cincinnati, OH       462.86         6.49
# 4  Nashville, TN         Seattle, WA      3865.20        51.90
#
#   weather_description  temperature_c
# 0       Partly cloudy           21.1
# 1               Sunny           13.9
# 2       Partly Cloudy           17.2
# 3            Overcast           19.4
# 4            Overcast            9.4

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
# Load base data
df_base = pd.read_csv("final_route_data.csv")

# Simulation parameters
total_rows = 196_000_000       
chunk_size = 1_000_000
chunks = total_rows // chunk_size

# Truck types with modifiers
truck_types = {
    "Light Duty": 1.00,
    "Medium Duty": 1.05,
    "Heavy Duty": 1.15,
    "Refrigerated": 1.10
}
truck_names = list(truck_types.keys())

# Output file name
output_file = "synthetic_shipping_data_21gb.csv"

# Final columns
columns = [
    'sourcecity', 'destinationcity', 'distance_km', 'duration_hr',
    'weather_description', 'temperature_c', 'truck_type', 'timestamp'
]

# %%
# Write header
with open(output_file, "w") as f:
    f.write(",".join(columns) + "\n")

print("Created output file with headers:", output_file)
# Out:
# Created output file with headers: synthetic_shipping_data_21gb.csv

# %%
print(" Starting simulation...")

for i in range(chunks):
    print(f" Generating chunk {i+1}/{chunks}")

    # Randomly select attributes
    trucks = np.random.choice(truck_names, chunk_size)
    modifiers = [truck_types[t] for t in trucks]

    data = {
        'sourcecity': np.random.choice(df_base['sourcecity'], chunk_size),
        'destinationcity': np.random.choice(df_base['destinationcity'], chunk_size),
        'distance_km': (
            np.random.choice(df_base['distance_km'], chunk_size) +
            np.random.normal(0, 10, chunk_size)  # simulate variation
        ),
        'weather_description': np.random.choice(df_base['weather_description'], chunk_size),
        'temperature_c': (
            np.random.choice(df_base['temperature_c'], chunk_size) +
            np.random.normal(0, 1.5, chunk_size)
        ),
        'truck_type': trucks,
        'timestamp': pd.date_range(start='2023-01-01', periods=chunk_size, freq='s')
    }

    df_chunk = pd.DataFrame(data)

    # Simulated duration with truck type modifier
    base_duration = (
        np.random.choice(df_base['duration_hr'], chunk_size) +
        np.random.normal(0, 1, chunk_size)
    )
    df_chunk['duration_hr'] = base_duration * [truck_types[t] for t in df_chunk['truck_type']]

    # Rearrange columns
    df_chunk = df_chunk[columns]

    # Append to CSV
    df_chunk.to_csv(output_file, mode='a', header=False, index=False)

    print(f" Chunk {i+1} written.")
# Out:
#  Starting simulation...
#  Generating chunk 1/196
#  Chunk 1 written.
#  Generating chunk 2/196
#  Chunk 2 written.
#  Generating chunk 3/196
#  Chunk 3 written.
#  Generating chunk 4/196
#  Chunk 4 written.
#  Generating chunk 5/196
#  Chunk 5 written.
#  Generating chunk 6/196
#  Chunk 6 written.
#  Generating chunk 7/196
#  Chunk 7 written.
#  Generating chunk 8/196
#  Chunk 8 written.
#  Generating chunk 9/196
#  Chunk 9 written.
#  Generating chunk 10/196
#  Chunk 10 written.
#  Generating chunk 11/196
#  Chunk 11 written.
#  Generating chunk 12/196
#  Chunk 12 written.
#  Generating chunk 13/196
#  Chunk 13 written.
#  Generating chunk 14/196
#  Chunk 14 written.
#  Generating chunk 15/196
#  Chunk 15 written.
#  Generating chunk 16/196
#  Chunk 16 written.
#  Generating chunk 17/196
#  Chunk 17 written.
#  Generating chunk 18/196
#  Chunk 18 written.
#  Generating chunk 19/196
#  Chunk 19 written.
#  Generating chunk 20/196
#  Chunk 20 written.
#  Generating chunk 21/196
#  Chunk 21 written.
#  Generating chunk 22/196
#  Chunk 22 written.
#  Generating chunk 23/196
#  Chunk 23 written.
#  Generating chunk 24/196
#  Chunk 24 written.
#  Generating chunk 25/196
#  Chunk 25 written.
#  Generating chunk 26/196
#  Chunk 26 written.
#  Generating chunk 27/196
#  Chunk 27 written.
#  Generating chunk 28/196
#  Chunk 28 written.
#  Generating chunk 29/196
#  Chunk 29 written.
#  Generating chunk 30/196
#  Chunk 30 written.
#  Generating chunk 31/196
#  Chunk 31 written.
#  Generating chunk 32/196
#  Chunk 32 written.
#  Generating chunk 33/196
#  Chunk 33 written.
#  Generating chunk 34/196
#  Chunk 34 written.
#  Generating chunk 35/196
#  Chunk 35 written.
#  Generating chunk 36/196
#  Chunk 36 written.
#  Generating chunk 37/196
#  Chunk 37 written.
#  Generating chunk 38/196
#  Chunk 38 written.
#  Generating chunk 39/196
#  Chunk 39 written.
#  Generating chunk 40/196
#  Chunk 40 written.
#  Generating chunk 41/196
#  Chunk 41 written.
#  Generating chunk 42/196
#  Chunk 42 written.
#  Generating chunk 43/196
#  Chunk 43 written.
#  Generating chunk 44/196
#  Chunk 44 written.
#  Generating chunk 45/196
#  Chunk 45 written.
#  Generating chunk 46/196
#  Chunk 46 written.
#  Generating chunk 47/196
#  Chunk 47 written.
#  Generating chunk 48/196
#  Chunk 48 written.
#  Generating chunk 49/196
#  Chunk 49 written.
#  Generating chunk 50/196
#  Chunk 50 written.
#  Generating chunk 51/196
#  Chunk 51 written.
#  Generating chunk 52/196
#  Chunk 52 written.
#  Generating chunk 53/196
#  Chunk 53 written.
#  Generating chunk 54/196
#  Chunk 54 written.
#  Generating chunk 55/196
#  Chunk 55 written.
#  Generating chunk 56/196
#  Chunk 56 written.
#  Generating chunk 57/196
#  Chunk 57 written.
#  Generating chunk 58/196
#  Chunk 58 written.
#  Generating chunk 59/196
#  Chunk 59 written.
#  Generating chunk 60/196
#  Chunk 60 written.
#  Generating chunk 61/196
#  Chunk 61 written.
#  Generating chunk 62/196
#  Chunk 62 written.
#  Generating chunk 63/196
#  Chunk 63 written.
#  Generating chunk 64/196
#  Chunk 64 written.
#  Generating chunk 65/196
#  Chunk 65 written.
#  Generating chunk 66/196
#  Chunk 66 written.
#  Generating chunk 67/196
#  Chunk 67 written.
#  Generating chunk 68/196
#  Chunk 68 written.
#  Generating chunk 69/196
#  Chunk 69 written.
#  Generating chunk 70/196
#  Chunk 70 written.
#  Generating chunk 71/196
#  Chunk 71 written.
#  Generating chunk 72/196
#  Chunk 72 written.
#  Generating chunk 73/196
#  Chunk 73 written.
#  Generating chunk 74/196
#  Chunk 74 written.
#  Generating chunk 75/196
#  Chunk 75 written.
#  Generating chunk 76/196
#  Chunk 76 written.
#  Generating chunk 77/196
#  Chunk 77 written.
#  Generating chunk 78/196
#  Chunk 78 written.
#  Generating chunk 79/196
#  Chunk 79 written.
#  Generating chunk 80/196
#  Chunk 80 written.
#  Generating chunk 81/196
#  Chunk 81 written.
#  Generating chunk 82/196
#  Chunk 82 written.
#  Generating chunk 83/196
#  Chunk 83 written.
#  Generating chunk 84/196
#  Chunk 84 written.
#  Generating chunk 85/196
#  Chunk 85 written.
#  Generating chunk 86/196
#  Chunk 86 written.
#  Generating chunk 87/196
#  Chunk 87 written.
#  Generating chunk 88/196
#  Chunk 88 written.
#  Generating chunk 89/196
#  Chunk 89 written.
#  Generating chunk 90/196
#  Chunk 90 written.
#  Generating chunk 91/196
#  Chunk 91 written.
#  Generating chunk 92/196
#  Chunk 92 written.
#  Generating chunk 93/196
#  Chunk 93 written.
#  Generating chunk 94/196
#  Chunk 94 written.
#  Generating chunk 95/196
#  Chunk 95 written.
#  Generating chunk 96/196
#  Chunk 96 written.
#  Generating chunk 97/196
#  Chunk 97 written.
#  Generating chunk 98/196
#  Chunk 98 written.
#  Generating chunk 99/196
#  Chunk 99 written.
#  Generating chunk 100/196
#  Chunk 100 written.
#  Generating chunk 101/196
#  Chunk 101 written.
#  Generating chunk 102/196
#  Chunk 102 written.
#  Generating chunk 103/196
#  Chunk 103 written.
#  Generating chunk 104/196
#  Chunk 104 written.
#  Generating chunk 105/196
#  Chunk 105 written.
#  Generating chunk 106/196
#  Chunk 106 written.
#  Generating chunk 107/196
#  Chunk 107 written.
#  Generating chunk 108/196
#  Chunk 108 written.
#  Generating chunk 109/196
#  Chunk 109 written.
#  Generating chunk 110/196
#  Chunk 110 written.
#  Generating chunk 111/196
#  Chunk 111 written.
#  Generating chunk 112/196
#  Chunk 112 written.
#  Generating chunk 113/196
#  Chunk 113 written.
#  Generating chunk 114/196
#  Chunk 114 written.
#  Generating chunk 115/196
#  Chunk 115 written.
#  Generating chunk 116/196
#  Chunk 116 written.
#  Generating chunk 117/196
#  Chunk 117 written.
#  Generating chunk 118/196
#  Chunk 118 written.
#  Generating chunk 119/196
#  Chunk 119 written.
#  Generating chunk 120/196
#  Chunk 120 written.
#  Generating chunk 121/196
#  Chunk 121 written.
#  Generating chunk 122/196
#  Chunk 122 written.
#  Generating chunk 123/196
#  Chunk 123 written.
#  Generating chunk 124/196
#  Chunk 124 written.
#  Generating chunk 125/196
#  Chunk 125 written.
#  Generating chunk 126/196
#  Chunk 126 written.
#  Generating chunk 127/196
#  Chunk 127 written.
#  Generating chunk 128/196
#  Chunk 128 written.
#  Generating chunk 129/196
#  Chunk 129 written.
#  Generating chunk 130/196
#  Chunk 130 written.
#  Generating chunk 131/196
#  Chunk 131 written.
#  Generating chunk 132/196
#  Chunk 132 written.
#  Generating chunk 133/196
#  Chunk 133 written.
#  Generating chunk 134/196
#  Chunk 134 written.
#  Generating chunk 135/196
#  Chunk 135 written.
#  Generating chunk 136/196
#  Chunk 136 written.
#  Generating chunk 137/196
#  Chunk 137 written.
#  Generating chunk 138/196
#  Chunk 138 written.
#  Generating chunk 139/196
#  Chunk 139 written.
#  Generating chunk 140/196
#  Chunk 140 written.
#  Generating chunk 141/196
#  Chunk 141 written.
#  Generating chunk 142/196
#  Chunk 142 written.
#  Generating chunk 143/196
#  Chunk 143 written.
#  Generating chunk 144/196
#  Chunk 144 written.
#  Generating chunk 145/196
#  Chunk 145 written.
#  Generating chunk 146/196
#  Chunk 146 written.
#  Generating chunk 147/196
#  Chunk 147 written.
#  Generating chunk 148/196
#  Chunk 148 written.
#  Generating chunk 149/196
#  Chunk 149 written.
#  Generating chunk 150/196
#  Chunk 150 written.
#  Generating chunk 151/196
#  Chunk 151 written.
#  Generating chunk 152/196
#  Chunk 152 written.
#  Generating chunk 153/196
#  Chunk 153 written.
#  Generating chunk 154/196
#  Chunk 154 written.
#  Generating chunk 155/196
#  Chunk 155 written.
#  Generating chunk 156/196
#  Chunk 156 written.
#  Generating chunk 157/196
#  Chunk 157 written.
#  Generating chunk 158/196
#  Chunk 158 written.
#  Generating chunk 159/196
#  Chunk 159 written.
#  Generating chunk 160/196
#  Chunk 160 written.
#  Generating chunk 161/196
#  Chunk 161 written.
#  Generating chunk 162/196
#  Chunk 162 written.
#  Generating chunk 163/196
#  Chunk 163 written.
#  Generating chunk 164/196
#  Chunk 164 written.
#  Generating chunk 165/196
#  Chunk 165 written.
#  Generating chunk 166/196
#  Chunk 166 written.
#  Generating chunk 167/196
#  Chunk 167 written.
#  Generating chunk 168/196
#  Chunk 168 written.
#  Generating chunk 169/196
#  Chunk 169 written.
#  Generating chunk 170/196
#  Chunk 170 written.
#  Generating chunk 171/196
#  Chunk 171 written.
#  Generating chunk 172/196
#  Chunk 172 written.
#  Generating chunk 173/196
#  Chunk 173 written.
#  Generating chunk 174/196
#  Chunk 174 written.
#  Generating chunk 175/196
#  Chunk 175 written.
#  Generating chunk 176/196
#  Chunk 176 written.
#  Generating chunk 177/196
#  Chunk 177 written.
#  Generating chunk 178/196
#  Chunk 178 written.
#  Generating chunk 179/196
#  Chunk 179 written.
#  Generating chunk 180/196
#  Chunk 180 written.
#  Generating chunk 181/196
#  Chunk 181 written.
#  Generating chunk 182/196
#  Chunk 182 written.
#  Generating chunk 183/196
#  Chunk 183 written.
#  Generating chunk 184/196
#  Chunk 184 written.
#  Generating chunk 185/196
#  Chunk 185 written.
#  Generating chunk 186/196
#  Chunk 186 written.
#  Generating chunk 187/196
#  Chunk 187 written.
#  Generating chunk 188/196
#  Chunk 188 written.
#  Generating chunk 189/196
#  Chunk 189 written.
#  Generating chunk 190/196
#  Chunk 190 written.
#  Generating chunk 191/196
#  Chunk 191 written.
#  Generating chunk 192/196
#  Chunk 192 written.
#  Generating chunk 193/196
#  Chunk 193 written.
#  Generating chunk 194/196
#  Chunk 194 written.
#  Generating chunk 195/196
#  Chunk 195 written.
#  Generating chunk 196/196
#  Chunk 196 written.

# %%
print("Simulation complete!")
print("File saved as:", output_file)
# Out:
# Simulation complete!
# File saved as: synthetic_shipping_data_21gb.csv

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("UploadCSVToHDFS") \
    .config("spark.hadoop.fs.defaultFS", "hdfs://localhost:9000") \
    .getOrCreate()

df = spark.read.csv("file:///home/varun/Desktop/synthetic_shipping_data_21gb.csv", header=True, inferSchema=True)

df.write \
  .option("header", True) \
  .mode("overwrite") \
  .csv("/user/varun/shipping_data")
# Out:
# 25/05/12 10:21:22 WARN Utils: Your hostname, ubuntu resolves to a loopback address: 127.0.1.1; using 10.0.2.15 instead (on interface enp0s3)
# 25/05/12 10:21:22 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/12 10:21:23 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, countDistinct, count, min, max, avg, expr

# Start Spark session
spark = SparkSession.builder \
    .appName("ShippingOptimizationEDA") \
    .config("spark.hadoop.fs.defaultFS", "hdfs://localhost:9000") \
    .getOrCreate()

# Read from HDFS (correct folder path)
df = spark.read \
    .option("header", True) \
    .csv("hdfs://localhost:9000/user/varun/shipping_data")

# Cast distance_km column to numeric
df = df.withColumn("distance_km", col("distance_km").cast("double"))

# Count total records
print(" Total records:", df.count())

# Distinct counts
df.select(countDistinct("sourcecity")).show(truncate=False)
df.select(countDistinct("destinationcity")).show(truncate=False)
df.select("sourcecity", "destinationcity").dropDuplicates().count()

# Distance stats
df.select(
    min("distance_km").alias("min_distance_km"),
    max("distance_km").alias("max_distance_km"),
    avg("distance_km").alias("avg_distance_km")
).show(truncate=False)

# Top 5 longest routes
print("\n Top 5 Longest Routes:")
df.select("sourcecity", "destinationcity", "distance_km") \
  .orderBy(col("distance_km").desc()) \
  .limit(5).show(truncate=False)

# Top 5 shortest non-zero routes
print("\n Top 5 Shortest Non-Zero Routes:")
df.filter(col("distance_km") > 0) \
  .select("sourcecity", "destinationcity", "distance_km") \
  .orderBy("distance_km") \
  .limit(5).show(truncate=False)
# Out:
# 25/05/12 10:39:08 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
#  Total records: 196000000
# +--------------------------+
# |count(DISTINCT sourcecity)|
# +--------------------------+
# |20                        |
# +--------------------------+
# +-------------------------------+
# |count(DISTINCT destinationcity)|
# +-------------------------------+
# |20                             |
# +-------------------------------+
# +------------------+-----------------+-----------------+
# |min_distance_km   |max_distance_km  |avg_distance_km  |
# +------------------+-----------------+-----------------+
# |29.961738244688476|5373.819321891454|2291.717263228566|
# +------------------+-----------------+-----------------+
#
#
#  Top 5 Longest Routes:
# +--------------+---------------+-----------------+
# |sourcecity    |destinationcity|distance_km      |
# +--------------+---------------+-----------------+
# |Detroit, MI   |Portland, OR   |5373.819321891454|
# |Washington, DC|Boston, MA     |5371.000621437923|
# |Boston, MA    |Nashville, TN  |5370.000870118544|
# |Orlando, FL   |Seattle, WA    |5369.942453249165|
# |Boise, ID     |Washington, DC |5368.114734215875|
# +--------------+---------------+-----------------+
#
#
#  Top 5 Shortest Non-Zero Routes:
# [Stage 30:=====================================================>(207 + 1) / 208]
# +--------------+------------------+------------------+
# |sourcecity    |destinationcity   |distance_km       |
# +--------------+------------------+------------------+
# |Boston, MA    |Portland, ME      |29.961738244688476|
# |Harrisburg, PA|Houston, TX       |30.01121087033956 |
# |Washington, DC|Denver, CO        |30.744669518569125|
# |Houston, TX   |Chicago, IL       |31.4749576989733  |
# |Houston, TX   |Salt Lake City, UT|31.60285341529176 |
# +--------------+------------------+------------------+

# %%
from pyspark.sql import SparkSession
import pandas as pd
import numpy as np
import random

spark = SparkSession.builder \
    .appName("ACO_FixedStartEnd") \
    .config("spark.hadoop.fs.defaultFS", "hdfs://localhost:9000") \
    .config("spark.driver.memory", "4g") \
    .getOrCreate()

df = spark.read \
    .option("header", True) \
    .csv("hdfs://localhost:9000/user/varun/shipping_data") \
    .select("sourcecity", "destinationcity", "distance_km") \
    .limit(1000)

df = df.withColumn("distance_km", df["distance_km"].cast("double"))
pdf = df.toPandas()

cities = sorted(set(pdf['sourcecity']).union(set(pdf['destinationcity'])))
city_index = {city: i for i, city in enumerate(cities)}
index_to_city = {i: city for city, i in city_index.items()}
n = len(cities)

start_candidates = [c for c in cities if "harrisburg" in c.lower()]
end_candidates = [c for c in cities if "new york" in c.lower()]

if not start_candidates or not end_candidates:
    raise ValueError("Could not find city matching 'Harrisburg' or 'New York'.")

start_city = start_candidates[0]
end_city = end_candidates[0]

start_index = city_index[start_city]
end_index = city_index[end_city]

dist_matrix = np.full((n, n), np.inf)
for _, row in pdf.iterrows():
    i, j = city_index[row['sourcecity']], city_index[row['destinationcity']]
    dist_matrix[i][j] = row['distance_km']

n_ants = 10
n_iterations = 30
alpha = 1.0
beta = 5.0
evaporation = 0.5
Q = 100

pheromones = np.ones((n, n))

def probability(i, visited):
    probs = []
    for j in range(n):
        if j in visited or dist_matrix[i][j] == np.inf:
            probs.append(0)
        else:
            probs.append((pheromones[i][j] ** alpha) * ((1 / dist_matrix[i][j]) ** beta))
    total = sum(probs)
    return [p / total if total > 0 else 0 for p in probs]

def route_length(route):
    return sum(dist_matrix[route[i]][route[i+1]] for i in range(len(route) - 1))

best_route = None
best_length = float('inf')

for _ in range(n_iterations):
    routes = []
    lengths = []
    for _ in range(n_ants):
        visited = [start_index]
        current = start_index
        while len(visited) < n - 1:
            probs = probability(current, visited + [end_index])
            if sum(probs) == 0:
                break
            next_city = np.random.choice(range(n), p=probs)
            if next_city != end_index:
                visited.append(next_city)
                current = next_city
        visited.append(end_index)
        if len(visited) == n:
            length = route_length(visited)
            routes.append(visited)
            lengths.append(length)
            if length < best_length:
                best_length = length
                best_route = visited
    pheromones *= (1 - evaporation)
    for route, length in zip(routes, lengths):
        for i in range(len(route) - 1):
            pheromones[route[i]][route[i+1]] += Q / length

aco_route = [index_to_city[i] for i in best_route] if best_route else []

print("ACO Start city:", start_city)
print("ACO End city:", end_city)
print("ACO Route:")
print(" ➝ ".join(aco_route))
print("ACO Total Distance (km):", round(best_length, 2) if best_route else "N/A")
# Out:
# 25/05/12 11:05:51 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# ACO Start city: Harrisburg, PA
# ACO End city: New York City, NY
# ACO Route:
# Harrisburg, PA ➝ Baltimore, MD ➝ Las Vegas, NV ➝ Denver, CO ➝ Cincinnati, OH ➝ Miami, FL ➝ Portland, ME ➝ Salt Lake City, UT ➝ Seattle, WA ➝ Boston, MA ➝ Boise, ID ➝ Houston, TX ➝ Portland, OR ➝ Nashville, TN ➝ Orlando, FL ➝ Chicago, IL ➝ Pittsburgh, PA ➝ Washington, DC ➝ Detroit, MI ➝ New York City, NY
# ACO Total Distance (km): 12576.04

# %%
from pyspark.sql import SparkSession
import pandas as pd
import numpy as np
import random

spark = SparkSession.builder \
    .appName("GA_FixedStartEnd") \
    .config("spark.hadoop.fs.defaultFS", "hdfs://localhost:9000") \
    .config("spark.driver.memory", "4g") \
    .getOrCreate()

df = spark.read \
    .option("header", True) \
    .csv("hdfs://localhost:9000/user/varun/shipping_data") \
    .select("sourcecity", "destinationcity", "distance_km") \
    .limit(1000)

df = df.withColumn("distance_km", df["distance_km"].cast("double"))
pdf = df.toPandas()

cities = sorted(set(pdf['sourcecity']).union(set(pdf['destinationcity'])))
city_index = {city: i for i, city in enumerate(cities)}
index_to_city = {i: city for city, i in city_index.items()}
n = len(cities)

start_candidates = [c for c in cities if "harrisburg" in c.lower()]
end_candidates = [c for c in cities if "new york" in c.lower()]

if not start_candidates or not end_candidates:
    raise ValueError("Could not find city matching 'Harrisburg' or 'New York'.")

start_city = start_candidates[0]
end_city = end_candidates[0]
start_index = city_index[start_city]
end_index = city_index[end_city]

dist_matrix = np.full((n, n), np.inf)
for _, row in pdf.iterrows():
    i, j = city_index[row['sourcecity']], city_index[row['destinationcity']]
    dist_matrix[i][j] = row['distance_km']

def total_distance(route):
    full_route = [start_index] + route + [end_index]
    return sum(dist_matrix[full_route[i]][full_route[i+1]] for i in range(len(full_route)-1))

def create_population(size):
    middle_cities = [i for i in range(n) if i not in (start_index, end_index)]
    return [random.sample(middle_cities, len(middle_cities)) for _ in range(size)]

def crossover(p1, p2):
    a, b = sorted(random.sample(range(len(p1)), 2))
    child = [-1] * len(p1)
    child[a:b] = p1[a:b]
    fill = [x for x in p2 if x not in child]
    pos = 0
    for i in range(len(p1)):
        if child[i] == -1:
            child[i] = fill[pos]
            pos += 1
    return child

def mutate(route, rate=0.01):
    for i in range(len(route)):
        if random.random() < rate:
            j = random.randint(0, len(route)-1)
            route[i], route[j] = route[j], route[i]
    return route

population_size = 50
generations = 100
mutation_rate = 0.02

population = create_population(population_size)

for _ in range(generations):
    population = sorted(population, key=total_distance)
    next_gen = population[:10]
    while len(next_gen) < population_size:
        p1, p2 = random.sample(population[:25], 2)
        child = crossover(p1, p2)
        child = mutate(child, mutation_rate)
        next_gen.append(child)
    population = next_gen

best_middle = population[0]
best_full = [start_index] + best_middle + [end_index]
best_distance = total_distance(best_middle)

ga_route = [index_to_city[i] for i in best_full]

print("GA Start city:", start_city)
print("GA End city:", end_city)
print("GA Route:")
print(" ➝ ".join(ga_route))
print("GA Total Distance (km):", round(best_distance, 2))
# Out:
# 25/05/12 11:06:01 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# GA Start city: Harrisburg, PA
# GA End city: New York City, NY
# GA Route:
# Harrisburg, PA ➝ Salt Lake City, UT ➝ Orlando, FL ➝ Chicago, IL ➝ Houston, TX ➝ Boston, MA ➝ Baltimore, MD ➝ Portland, OR ➝ Nashville, TN ➝ Portland, ME ➝ Boise, ID ➝ Seattle, WA ➝ Pittsburgh, PA ➝ Washington, DC ➝ Las Vegas, NV ➝ Denver, CO ➝ Cincinnati, OH ➝ Miami, FL ➝ Detroit, MI ➝ New York City, NY
# GA Total Distance (km): 14305.87

# %%
pip install folium geopy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in /home/varun/.local/lib/python3.10/site-packages (0.19.5)
# Requirement already satisfied: geopy in /home/varun/.local/lib/python3.10/site-packages (2.4.1)
# Requirement already satisfied: branca>=0.6.0 in /home/varun/.local/lib/python3.10/site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /home/varun/.local/lib/python3.10/site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /home/varun/.local/lib/python3.10/site-packages (from folium) (2.2.5)
# Requirement already satisfied: requests in /home/varun/.local/lib/python3.10/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /home/varun/.local/lib/python3.10/site-packages (from folium) (2025.4.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /home/varun/.local/lib/python3.10/site-packages (from geopy) (2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/varun/.local/lib/python3.10/site-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->folium) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->folium) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->folium) (2020.6.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# Coordinates for all possible cities in your dataset
city_coords = {
    "Harrisburg, PA": (40.2732, -76.8867),
    "Houston, TX": (29.7604, -95.3698),
    "Denver, CO": (39.7392, -104.9903),
    "Miami, FL": (25.7617, -80.1918),
    "Baltimore, MD": (39.2904, -76.6122),
    "Orlando, FL": (28.5383, -81.3792),
    "Las Vegas, NV": (36.1699, -115.1398),
    "Boise, ID": (43.6150, -116.2023),
    "Nashville, TN": (36.1627, -86.7816),
    "Salt Lake City, UT": (40.7608, -111.8910),
    "Portland, ME": (43.6591, -70.2568),
    "Boston, MA": (42.3601, -71.0589),
    "Detroit, MI": (42.3314, -83.0458),
    "Chicago, IL": (41.8781, -87.6298),
    "Cincinnati, OH": (39.1031, -84.5120),
    "Pittsburgh, PA": (40.4406, -79.9959),
    "Portland, OR": (45.5051, -122.6750),
    "Washington, DC": (38.9072, -77.0369),
    "Seattle, WA": (47.6062, -122.3321),
    "New York City, NY": (40.7128, -74.0060)
}

# Helper: get coordinates from route
def coords_from_route(route):
    return [city_coords[city] for city in route if city in city_coords]

# Get coordinates
aco_coords = coords_from_route(aco_route)
ga_coords = coords_from_route(ga_route)

# Center the map roughly at the midpoint of GA route
midpoint = ga_coords[len(ga_coords)//2]
m = folium.Map(location=midpoint, zoom_start=5)

# Draw routes
folium.PolyLine(aco_coords, color="blue", weight=4, tooltip="ACO Route").add_to(m)
folium.PolyLine(ga_coords, color="green", weight=4, tooltip="GA Route").add_to(m)

# Add markers
for city in set(aco_route + ga_route):
    if city in city_coords:
        folium.Marker(location=city_coords[city], tooltip=city).add_to(m)

# Highlight start/end for both routes
folium.Marker(location=city_coords[aco_route[0]], icon=folium.Icon(color='red'), tooltip="Start (ACO)").add_to(m)
folium.Marker(location=city_coords[aco_route[-1]], icon=folium.Icon(color='darkred'), tooltip="End (ACO)").add_to(m)
folium.Marker(location=city_coords[ga_route[0]], icon=folium.Icon(color='green'), tooltip="Start (GA)").add_to(m)
folium.Marker(location=city_coords[ga_route[-1]], icon=folium.Icon(color='darkgreen'), tooltip="End (GA)").add_to(m)

# Save the map
m.save("combined_route_map1.html")
